# %% [markdown]
# # FEATURE ENGINEERING ASSIGNMENT
#
# 1.  What is a parameter?
#     - a parameter refers to a configuration variable that is internal to the model and whose value is learned from the training data.
#
# 2.  What is correlation What does negative correlation mean?
#     - correlation(r) define that how closely two variable move together
#     - if r=0 i.e no correlation
#     - if r =1 i.e perfect positive correlation
#     - if r = -1 i.e perfect negative correlation
#     - negative correlation means one variable is increasing and other is decreasing
#
# 3.  Define Machine Learning. What are the main components in Machine Learning?
#     - machine learing is a branch of artifical intelligence that  learning pattern from data, and replicate same in future
#     - to understand the mathemetical relationship
#     - main component of machine learning are Data, Model , Feature , Algorithm , Optimaisation
#
# 4.  How does loss value help in determining whether the model is good or not?
#     - it help in measure prediction error, compare other model , warnings for underfitting and overfitting
#
# 5.  What are continuous and categorical variables?
#     - continous variable can take any vlaue in a range and it play very crucial role in machine learning
#     - categorical variable are the variable that display a group or category
#
# 6.  How do we handle categorical variables in Machine Learning? What are the common techniques?
#     - we can handel categorical variable by label encoding and ordinal encoding and target encoding
#
# 7.  What do you mean by training and testing a dataset?
#     - if we have 100% data then we give 70% in traning of model and 30% data in testing of model
#      - in school we train studient and then validate student by taking internal exam and then we test them by taking external test
#
# 8.  What is sklearn.preprocessing?
#     - from sklearn.preprocessing is use to import many dataset like mode , correlation , label encoder , Normilizer
#     - it is a module in python
#
# 9.  What is a Test set?
#     - it is a portion of dataset that is not use for traning the data but is use for evulate the model that it is perfectvely made or not
#
# 10.  How do we split data for model fitting (training and testing) in Python?
#      - we split data to minimize the error of model
#      - fristly import train_test_split from sklearn_model_selection
#      - 2nd :- make data , and by some basic formate we do spliting
#
# 11.  Why do we have to perform EDA before fitting a model to the data?
#      - EDA(exploratoey data analysis ) is a cross industry standard process for data warning
#      - EDA is perform for data understanding that now much data is numerical and how much is object and how much is float and to convert it into numerical formate
#
# 12.  What is correlation?
#      - it is a statistical measure that describe relation between two variable
#      - if r=0 i.e no correlation
#      - if r =1 i.e perfect positive correlation
#      - if r = -1 i.e perfect negative correlation
#
# 13.  What does negative correlation mean?
#      - negative correlation means one variable is increasing and other is decreasing
#
# 14.  How can you find correlation between variables in Python?
#      - frist import pandas as pd
#      - then make pd.DataFrame()
#      - then make corr_matrix = df.corr()
#      - then print(corr_matrix)
#
# 15.  What is causation? Explain difference between correlation and causation with an example?
#      - it means one event directly cause another to happen
#      - correlation means variable are related to each other
#      - correlation can exist without causation but casation implies correlation
#
# 16.  What is an Optimizer? What are different types of optimizers? Explain each with an example?
#      - it is a algorithm use to adjust the parameter of a machine learning model
#      - it is use to minimize the loss during traning
#      - types are :- GD, SGD, momentum, Adagrad
#
# 17.  What is sklearn.linear_model ?
#      -it is a module in sckit.learn that provide linear model for regression
#
# 18.  What does model.fit() do? What arguments must be given?
#      - it is use to train a machine learning modle using traning data
#      - argument are input variable and target variable
#
# 19.  What does model.predict() do? What arguments must be given?
#      - it is used to make prediction of trained model
#      -Once you've trained (fit) your model on some data, you use predict() to estimate outcomes for new, unseen input data.
#
# 21.  What is feature scaling? How does it help in Machine Learning?
#      - it tries to live all the feature on same scale
